# %%
import pandas as pd
from bs4 import BeautifulSoup
from urllib.request import urlopen
import re

# %%
url ="https://pt.wikipedia.org/wiki/Lista_de_munic%C3%ADpios_do_Brasil"
html = urlopen(url)

# %%
print(html)
# Out:
# <http.client.HTTPResponse object at 0x000001D51CF54670>

# %%
soup = BeautifulSoup(html, "html.parser")

# %%
padrao_estado=re.compile(" \([A-Z]{2}\)")

# %%
df= pd.DataFrame(columns=(["cidade", "estado"]))
for linha in soup.find_all("li"):
  
        if padrao_estado.search(linha.text):
            #print(linha.text) exibindo os dados
            #print(re.split(" \(",linha.text.replace(")",""))) # tratando os dados
            dados=re.split(" \(",linha.text.replace(")",""))
            df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# Out:
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# ...
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3844/2857759490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"cidade": dados[0], "estado": dados[1]}, ignore_index=True)

# %%
df.head()
# Out:
#                 cidade estado
# 0      Abadia de Goiás     GO
# 1  Abadia dos Dourados     MG
# 2            Abadiânia     GO
# 3               Abaeté     MG
# 4           Abaetetuba     PA
